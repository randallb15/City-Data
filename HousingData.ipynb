# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
housing_df = pd.read_stata('data/116215-V1/housing_inventory/clean_combined.dta')

# %%
housing_df.sample(2)
# Out:
#      year  median_rent  housing_units  net_new_housing  employment  \
# 44   1950        115.0       277836.0           3264.0         NaN
# 110  2016       3650.0            NaN              NaN         NaN
#
#      total_wages    cpi  adj_median_rent
# 44           NaN  0.242       475.206604
# 110          NaN    NaN              NaN

# %%
plt.plot(housing_df.housing_units)

# %%
plt.plot(housing_df.median_rent)

# %%
plt.plot(housing_df.net_new_housing)

# %%
plt.plot(housing_df.employment)

# %%
plt.plot(housing_df.total_wages)

# %%
plt.plot(housing_df.cpi)

# %%
plt.plot(housing_df.adj_median_rent)
